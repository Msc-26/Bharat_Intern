# %%
from skimage import io
image =io.imread(r"C:\Users\Acer\Downloads\download.png")
io.imshow(image)

# %%
##  importing libraries

# Reading the data
import pandas as pd
import numpy as np

# Visualization the data
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                names=["Sepal_Length_in_cm","Sepal_Width_in_cm","Petal_Length_in_cm","Petal_Width_in_cm","Species_Flower"])

# %%
# Printing the first five rows of dataset
data.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm Species_Flower
# 0                0.2    Iris-setosa
# 1                0.2    Iris-setosa
# 2                0.2    Iris-setosa
# 3                0.2    Iris-setosa
# 4                0.2    Iris-setosa

# %%
# Printing the last five rows of dataset
data.tail()
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm  Species_Flower
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica

# %%
# Printing the number of rows and columns 
print("The number of rows and columns respectively are",data.shape)
# Out:
# The number of rows and columns respectively are (150, 5)

# %%
# Printing the name of columns/attributes
print("The number of rows and columns respectively are",data.columns)
# Out:
# The number of rows and columns respectively are Index(['Sepal_Length_in_cm', 'Sepal_Width_in_cm', 'Petal_Length_in_cm',
#        'Petal_Width_in_cm', 'Species_Flower'],
#       dtype='object')

# %%
# Information of Dataset
data.info
# Out:
# <bound method DataFrame.info of      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm  Species_Flower
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
# Finding the missing values 
data.isnull().sum()
# Out:
# Sepal_Length_in_cm    0
# Sepal_Width_in_cm     0
# Petal_Length_in_cm    0
# Petal_Width_in_cm     0
# Species_Flower        0
# dtype: int64

# %%
# Finding duplicates
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
# Printing the datatype of attributes
print(" The datatype of attributes are \n",data.dtypes)
# Out:
#  The datatype of attributes are
#  Sepal_Length_in_cm    float64
# Sepal_Width_in_cm     float64
# Petal_Length_in_cm    float64
# Petal_Width_in_cm     float64
# Species_Flower         object
# dtype: object

# %%
# Fetching unique values of Species
data['Species_Flower'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Statistical Analysis 
print("The statistical analysis:\n",data.describe().T)
# Out:
# The statistical analysis:
#                      count      mean       std  min  25%   50%  75%  max
# Sepal_Length_in_cm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal_Width_in_cm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# Petal_Length_in_cm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# Petal_Width_in_cm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# Data Visualization

# %%
# Univariate Analysis

# %%
## Distribution of data
plt.figure(figsize=(12,12),facecolor='pink')
columnnumber=1

for column in data:
    if columnnumber<=4:
        ax=plt.subplot(2,2,columnnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    columnnumber+=1
plt.show()

# %%
## Boxplot
plt.boxplot(data['Sepal_Width_in_cm'])
# Observation: upper outliers and lower outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228e8ed98d0>,
#   <matplotlib.lines.Line2D at 0x228eb052250>],
#  'caps': [<matplotlib.lines.Line2D at 0x228eb052b10>,
#   <matplotlib.lines.Line2D at 0x228eb0533d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228eb027450>],
#  'medians': [<matplotlib.lines.Line2D at 0x228eb053ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228eb0642d0>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Sepal_Length_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228eb0bcc50>,
#   <matplotlib.lines.Line2D at 0x228eb0bd610>],
#  'caps': [<matplotlib.lines.Line2D at 0x228eb0bded0>,
#   <matplotlib.lines.Line2D at 0x228eb0be6d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228eb0bc350>],
#  'medians': [<matplotlib.lines.Line2D at 0x228eb0befd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228eb0bf890>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Petal_Width_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228eb116ed0>,
#   <matplotlib.lines.Line2D at 0x228eb117f50>],
#  'caps': [<matplotlib.lines.Line2D at 0x228eb124950>,
#   <matplotlib.lines.Line2D at 0x228eb125090>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228eb117050>],
#  'medians': [<matplotlib.lines.Line2D at 0x228eb125a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228eb117f10>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Petal_Length_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228eb176ed0>,
#   <matplotlib.lines.Line2D at 0x228eb177650>],
#  'caps': [<matplotlib.lines.Line2D at 0x228eb177f50>,
#   <matplotlib.lines.Line2D at 0x228eb188850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228eb176550>],
#  'medians': [<matplotlib.lines.Line2D at 0x228eb1890d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228eb189950>],
#  'means': []}

# %%
## Bivariate Analysis

fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
sns.scatterplot(x='Sepal_Length_in_cm',y='Petal_Length_in_cm',data=data,hue='Species_Flower',ax=ax1)
sns.scatterplot(x='Sepal_Width_in_cm',y='Petal_Width_in_cm',data=data,hue='Species_Flower',ax=ax2)
# Out:
# <Axes: xlabel='Sepal_Width_in_cm', ylabel='Petal_Width_in_cm'>

# %%
numeric_data = data.select_dtypes(include='number')  # Select only numeric columns
sns.heatmap(numeric_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
## Encoding
le = LabelEncoder()
data['Species_Flower'] = le.fit_transform = (data['Species_Flower'])
data.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm Species_Flower
# 0                0.2    Iris-setosa
# 1                0.2    Iris-setosa
# 2                0.2    Iris-setosa
# 3                0.2    Iris-setosa
# 4                0.2    Iris-setosa

# %%
## Independent Features
X = data.drop(columns=['Species_Flower'])
X
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 4 columns]

# %%
## Independent Feature
y = data['Species_Flower']
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species_Flower, Length: 150, dtype: object

# %%
## Splitting the model
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.3)

# %%
## Training the model
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
## printing coefficient of model
print(log_reg.coef_)
# Out:
# [[-0.43453635  0.83444308 -2.2264195  -0.97038698]
#  [ 0.51725043 -0.53660379 -0.09688849 -0.79967662]
#  [-0.08271408 -0.29783929  2.32330799  1.7700636 ]]

# %%
## printing intercept of model
print(log_reg.intercept_)
# Out:
# [  8.9609354    1.99355643 -10.95449183]

# %%
## Printing Training Score
print('Training Score:',log_reg.score(X_train,y_train))
# Out:
# Training Score: 0.9619047619047619

# %%
## Printing Test Score
print('Test Score:',log_reg.score(X_test,y_test))
# Out:
# Test Score: 0.9777777777777777

# %%
## predicting for test data
y_pred =log_reg.predict(X_test)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor'], dtype=object)

# %%
## Creating Dataframe predictions
predictions=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
predictions
# Out:
#               Actual        Predicted
# 143   Iris-virginica   Iris-virginica
# 76   Iris-versicolor  Iris-versicolor
# 86   Iris-versicolor  Iris-versicolor
# 75   Iris-versicolor  Iris-versicolor
# 110   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 63   Iris-versicolor  Iris-versicolor
# 9        Iris-setosa      Iris-setosa
# 13       Iris-setosa      Iris-setosa
# 140   Iris-virginica   Iris-virginica
# 107   Iris-virginica   Iris-virginica
# 58   Iris-versicolor  Iris-versicolor
# 57   Iris-versicolor  Iris-versicolor
# 141   Iris-virginica   Iris-virginica
# 123   Iris-virginica   Iris-virginica
# 90   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 139   Iris-virginica   Iris-virginica
# 136   Iris-virginica   Iris-virginica
# 91   Iris-versicolor  Iris-versicolor
# 15       Iris-setosa      Iris-setosa
# 23       Iris-setosa      Iris-setosa
# 118   Iris-virginica   Iris-virginica
# 52   Iris-versicolor  Iris-versicolor
# 33       Iris-setosa      Iris-setosa
# 12       Iris-setosa      Iris-setosa
# 122   Iris-virginica   Iris-virginica
# 104   Iris-virginica   Iris-virginica
# 59   Iris-versicolor  Iris-versicolor
# 144   Iris-virginica   Iris-virginica
# 94   Iris-versicolor  Iris-versicolor
# 4        Iris-setosa      Iris-setosa
# 56   Iris-versicolor  Iris-versicolor
# 45       Iris-setosa      Iris-setosa
# 53   Iris-versicolor  Iris-versicolor
# 111   Iris-virginica   Iris-virginica
# 97   Iris-versicolor  Iris-versicolor
# 21       Iris-setosa      Iris-setosa
# 138   Iris-virginica   Iris-virginica
# 85   Iris-versicolor  Iris-versicolor
# 61   Iris-versicolor  Iris-versicolor
# 102   Iris-virginica   Iris-virginica
# 70   Iris-versicolor   Iris-virginica
# 133   Iris-virginica   Iris-virginica
# 67   Iris-versicolor  Iris-versicolor

# %%
## confusion matrix

conf_matrix= confusion_matrix(y_test,y_pred)
conf_matrix
# Out:
# array([[10,  0,  0],
#        [ 0, 17,  1],
#        [ 0,  0, 17]], dtype=int64)

# %%
## Computing Accuracy
accuracy= accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9777777777777777

# %%
## Computing False positive
False_positive =conf_matrix[0][1]
False_positive
# Out:
# 0

# %%
## Computing True Negative
True_negative=conf_matrix[1][1]
True_negative
# Out:
# 17

# %%
## Computing True positive
True_positive=conf_matrix[0][0]
True_positive
# Out:
# 10

# %%
## Computing Precision
Precision= True_positive/(True_positive+False_positive)
Precision
# Out:
# 1.0

# %%
## Computing False negative
False_negative =conf_matrix[1][0]
False_negative
# Out:
# 0

# %%
## Computing Recall
Recall= True_positive/(True_positive+False_negative)
Recall
# Out:
# 1.0

# %%
## Computing F1 Score
f1_Score=2*(Precision*Recall)/(Recall+Precision)

# %%
## Printing Classification Report
Classification_Report= classification_report(y_test,y_pred)
print(Classification_Report)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      0.94      0.97        18
#  Iris-virginica       0.94      1.00      0.97        17
#
#        accuracy                           0.98        45
#       macro avg       0.98      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
## Plotting Confusion Matrix
fig,ax=plt.subplots(figsize=(8,8))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i,j],va='center',ha='center',size='x-large')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix',fontsize=18)
plt.show()

# %%
print("The accuracy of the model:",accuracy)
# Out:
# The accuracy of the model: 0.9777777777777777
