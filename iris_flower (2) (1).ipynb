# %%
from skimage import io
image =io.imread(r"C:\Users\Acer\Downloads\download.png")
io.imshow(image)

# %%
##  importing libraries

# Reading the data
import pandas as pd
import numpy as np

# Visualization the data
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix

# Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',
                names=["Sepal_Length_in_cm","Sepal_Width_in_cm","Petal_Length_in_cm","Petal_Width_in_cm","Species_Flower"])

# %%
# Printing the first five rows of dataset
data.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm Species_Flower
# 0                0.2    Iris-setosa
# 1                0.2    Iris-setosa
# 2                0.2    Iris-setosa
# 3                0.2    Iris-setosa
# 4                0.2    Iris-setosa

# %%
# Printing the last five rows of dataset
data.tail()
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm  Species_Flower
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica

# %%
# Printing the number of rows and columns 
print("The number of rows and columns respectively are",data.shape)
# Out:
# The number of rows and columns respectively are (150, 5)

# %%
# Printing the name of columns/attributes
print("The number of rows and columns respectively are",data.columns)
# Out:
# The number of rows and columns respectively are Index(['Sepal_Length_in_cm', 'Sepal_Width_in_cm', 'Petal_Length_in_cm',
#        'Petal_Width_in_cm', 'Species_Flower'],
#       dtype='object')

# %%
# Information of Dataset
data.info
# Out:
# <bound method DataFrame.info of      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm  Species_Flower
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
# Finding the missing values 
data.isnull().sum()
# Out:
# Sepal_Length_in_cm    0
# Sepal_Width_in_cm     0
# Petal_Length_in_cm    0
# Petal_Width_in_cm     0
# Species_Flower        0
# dtype: int64

# %%
# Finding duplicates
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
# Printing the datatype of attributes
print(" The datatype of attributes are \n",data.dtypes)
# Out:
#  The datatype of attributes are
#  Sepal_Length_in_cm    float64
# Sepal_Width_in_cm     float64
# Petal_Length_in_cm    float64
# Petal_Width_in_cm     float64
# Species_Flower         object
# dtype: object

# %%
# Fetching unique values of Species
data['Species_Flower'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Statistical Analysis 
print("The statistical analysis:\n",data.describe().T)
# Out:
# The statistical analysis:
#                      count      mean       std  min  25%   50%  75%  max
# Sepal_Length_in_cm  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# Sepal_Width_in_cm   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# Petal_Length_in_cm  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# Petal_Width_in_cm   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %% [markdown]
# Data Visualization

# %%
# Univariate Analysis

# %%
## Distribution of data
plt.figure(figsize=(12,12),facecolor='pink')
columnnumber=1

for column in data:
    if columnnumber<=4:
        ax=plt.subplot(2,2,columnnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
    columnnumber+=1
plt.show()

# %%
## Boxplot
plt.boxplot(data['Sepal_Width_in_cm'])
# Observation: upper outliers and lower outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228e51e1010>,
#   <matplotlib.lines.Line2D at 0x228e51e1d50>],
#  'caps': [<matplotlib.lines.Line2D at 0x228e51e29d0>,
#   <matplotlib.lines.Line2D at 0x228e51e34d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228e51e0390>],
#  'medians': [<matplotlib.lines.Line2D at 0x228e51e3ed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228e51b4550>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Sepal_Length_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228e5230310>,
#   <matplotlib.lines.Line2D at 0x228e523db50>],
#  'caps': [<matplotlib.lines.Line2D at 0x228e523e610>,
#   <matplotlib.lines.Line2D at 0x228e523f010>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228e523c510>],
#  'medians': [<matplotlib.lines.Line2D at 0x228e523fc10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228e51fc6d0>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Petal_Width_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228e52a3410>,
#   <matplotlib.lines.Line2D at 0x228e52a3f50>],
#  'caps': [<matplotlib.lines.Line2D at 0x228e52aca50>,
#   <matplotlib.lines.Line2D at 0x228e52ad4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228e52a2810>],
#  'medians': [<matplotlib.lines.Line2D at 0x228e52adfd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228e51fe990>],
#  'means': []}

# %%
## Boxplot
plt.boxplot(data['Petal_Length_in_cm'])
# Observation: no outlier detected
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x228e530a990>,
#   <matplotlib.lines.Line2D at 0x228e530b610>],
#  'caps': [<matplotlib.lines.Line2D at 0x228e5314110>,
#   <matplotlib.lines.Line2D at 0x228e5314b50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x228e5309cd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x228e5315690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x228e5316110>],
#  'means': []}

# %%
## Bivariate Analysis

fig,(ax1,ax2)=plt.subplots(ncols=2,figsize=(16,5))
sns.scatterplot(x='Sepal_Length_in_cm',y='Petal_Length_in_cm',data=data,hue='Species_Flower',ax=ax1)
sns.scatterplot(x='Sepal_Width_in_cm',y='Petal_Width_in_cm',data=data,hue='Species_Flower',ax=ax2)
# Out:
# <Axes: xlabel='Sepal_Width_in_cm', ylabel='Petal_Width_in_cm'>

# %%
# Multivariate Analysis
# HeatMap
sns.set(rc={'figure.figsize':(10,8)})
sns.heatmap(data.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       1 # Multivariate Analysis
#       2 # HeatMap
#       3 sns.set(rc={'figure.figsize':(10,8)})
# ----> 4 sns.heatmap(data.corr(),annot=True)
#
# File C:\python\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\python\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File C:\python\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File C:\python\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Iris-setosa'

# %%
sns.pairplot(data,hue="Species_Flower")

# %%
## Encoding
le = LabelEncoder()
data['Species_Flower'] = le.fit_transform = (data['Species_Flower'])
data.head()
# Out:
#    Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                 5.1                3.5                 1.4
# 1                 4.9                3.0                 1.4
# 2                 4.7                3.2                 1.3
# 3                 4.6                3.1                 1.5
# 4                 5.0                3.6                 1.4
#
#    Petal_Width_in_cm Species_Flower
# 0                0.2    Iris-setosa
# 1                0.2    Iris-setosa
# 2                0.2    Iris-setosa
# 3                0.2    Iris-setosa
# 4                0.2    Iris-setosa

# %%
## Independent Features
X = data.drop(columns=['Species_Flower'])
X
# Out:
#      Sepal_Length_in_cm  Sepal_Width_in_cm  Petal_Length_in_cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      Petal_Width_in_cm
# 0                  0.2
# 1                  0.2
# 2                  0.2
# 3                  0.2
# 4                  0.2
# ..                 ...
# 145                2.3
# 146                1.9
# 147                2.0
# 148                2.3
# 149                1.8
#
# [150 rows x 4 columns]

# %%
## Independent Feature
y = data['Species_Flower']
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species_Flower, Length: 150, dtype: object

# %%
## Splitting the model
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.3)

# %%
## Training the model
log_reg=LogisticRegression()
log_reg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
## printing coefficient of model
print(log_reg.coef_)
# Out:
# [[-0.42030828  0.84951782 -2.30155234 -0.93956657]
#  [ 0.445554   -0.1345109  -0.14821245 -0.74203873]
#  [-0.02524571 -0.71500692  2.44976479  1.6816053 ]]

# %%
## printing intercept of model
print(log_reg.intercept_)
# Out:
# [  9.21039577   1.53313882 -10.74353459]

# %%
## Printing Training Score
print('Training Score:',log_reg.score(X_train,y_train))
# Out:
# Training Score: 0.9809523809523809

# %%
## Printing Test Score
print('Test Score:',log_reg.score(X_test,y_test))
# Out:
# Test Score: 0.9777777777777777

# %%
## predicting for test data
y_pred =log_reg.predict(X_test)
y_pred
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-versicolor'], dtype=object)

# %%
## Creating Dataframe predictions
predictions=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
predictions
# Out:
#               Actual        Predicted
# 14       Iris-setosa      Iris-setosa
# 98   Iris-versicolor  Iris-versicolor
# 124   Iris-virginica   Iris-virginica
# 7        Iris-setosa      Iris-setosa
# 17       Iris-setosa      Iris-setosa
# 51   Iris-versicolor  Iris-versicolor
# 48       Iris-setosa      Iris-setosa
# 143   Iris-virginica   Iris-virginica
# 120   Iris-virginica   Iris-virginica
# 138   Iris-virginica  Iris-versicolor
# 31       Iris-setosa      Iris-setosa
# 66   Iris-versicolor  Iris-versicolor
# 101   Iris-virginica   Iris-virginica
# 10       Iris-setosa      Iris-setosa
# 54   Iris-versicolor  Iris-versicolor
# 114   Iris-virginica   Iris-virginica
# 89   Iris-versicolor  Iris-versicolor
# 30       Iris-setosa      Iris-setosa
# 50   Iris-versicolor  Iris-versicolor
# 140   Iris-virginica   Iris-virginica
# 141   Iris-virginica   Iris-virginica
# 127   Iris-virginica   Iris-virginica
# 72   Iris-versicolor  Iris-versicolor
# 134   Iris-virginica   Iris-virginica
# 41       Iris-setosa      Iris-setosa
# 21       Iris-setosa      Iris-setosa
# 25       Iris-setosa      Iris-setosa
# 113   Iris-virginica   Iris-virginica
# 137   Iris-virginica   Iris-virginica
# 110   Iris-virginica   Iris-virginica
# 103   Iris-virginica   Iris-virginica
# 45       Iris-setosa      Iris-setosa
# 128   Iris-virginica   Iris-virginica
# 90   Iris-versicolor  Iris-versicolor
# 147   Iris-virginica   Iris-virginica
# 47       Iris-setosa      Iris-setosa
# 79   Iris-versicolor  Iris-versicolor
# 55   Iris-versicolor  Iris-versicolor
# 16       Iris-setosa      Iris-setosa
# 5        Iris-setosa      Iris-setosa
# 44       Iris-setosa      Iris-setosa
# 32       Iris-setosa      Iris-setosa
# 53   Iris-versicolor  Iris-versicolor
# 8        Iris-setosa      Iris-setosa
# 59   Iris-versicolor  Iris-versicolor

# %%
## confusion matrix

conf_matrix= confusion_matrix(y_test,y_pred)
conf_matrix
# Out:
# array([[17,  0,  0],
#        [ 0, 12,  0],
#        [ 0,  1, 15]], dtype=int64)

# %%
## Computing Accuracy
accuracy= accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9777777777777777

# %%
## Computing False positive
False_positive =conf_matrix[0][1]
False_positive
# Out:
# 0

# %%
## Computing True Negative
True_negative=conf_matrix[1][1]
True_negative
# Out:
# 12

# %%
## Computing True positive
True_positive=conf_matrix[0][0]
True_positive
# Out:
# 17

# %%
## Computing Precision
Precision= True_positive/(True_positive+False_positive)
Precision
# Out:
# 1.0

# %%
## Computing False negative
False_negative =conf_matrix[1][0]
False_negative
# Out:
# 0

# %%
## Computing Recall
Recall= True_positive/(True_positive+False_negative)
Recall
# Out:
# 1.0

# %%
## Computing F1 Score
f1_Score=2*(Precision*Recall)/(Recall+Precision)

# %%
## Printing Classification Report
Classification_Report= classification_report(y_test,y_pred)
print(Classification_Report)
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        17
# Iris-versicolor       0.92      1.00      0.96        12
#  Iris-virginica       1.00      0.94      0.97        16
#
#        accuracy                           0.98        45
#       macro avg       0.97      0.98      0.98        45
#    weighted avg       0.98      0.98      0.98        45

# %%
## Plotting Confusion Matrix
fig,ax=plt.subplots(figsize=(8,8))
ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i,j],va='center',ha='center',size='x-large')
plt.xlabel('Predictions',fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix',fontsize=18)
plt.show()

# %%
print("The accuracy of the model:",accuracy)
# Out:
# The accuracy of the model: 0.9777777777777777
